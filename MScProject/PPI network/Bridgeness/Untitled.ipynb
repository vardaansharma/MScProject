# %%
import pandas as pd

# %%
thefile  = pd.read_csv('PPI_Network/PPI_Network_Measures.csv',sep='\t',index_col='ENTREZ.ID')

thefile.head()

diff3 = pd.read_csv('Diff_exp3.csv',header=None)
diff3 = list(diff3[0])
diff2 = pd.read_csv('Diff_exp2.csv',header=None)
diff2 = list(diff2[0])
diff = pd.read_csv('Diffrentially_Expressed.csv',header=None)
diff = list(diff[0])
# diff3

thefile['DE'] = 0
thefile.head()

diff3
# Out:
# [10801, 4735, 6853, 80725]

# %%
thefile.columns.values
thefile.index
# thefile.loc[[273,1759,1785]]

a = [93185, 4099, 2819, 134, 2823, 4744, 84617, 3848, 3849, 79751, 526, 9615, 219537, 3858, 4884, 794, 5019, 3615, 4897, 2596, 292, 25769, 25902, 50, 348980, 308, 1462, 1345, 961, 55753, 586, 203, 2892, 2891, 2893, 4817, 8402, 54996, 478, 5091, 4199, 5095, 622, 6512, 100526833, 23154, 7923, 4724, 1653, 4340, 4978, 126328, 55163, 57468, 8574]
len(a)
len(diff)
# diff = diff - a
diff = [x for x in diff if x not in a]
a = [9751, 3848, 2891, 2892, 2893, 3858, 23154, 478,79751]
diff2 = [x for x in diff2 if x not in a]

thefile.loc[diff,['DE']] = 1
thefile.loc[diff3,['DE']] = 3
thefile.loc[diff2,['DE']] = 2
# thefile.head()
thefile.loc[diff3]

thefile.loc[diff]
# len(thefile)
# thefile.to_csv('Measures_with_DE.csv')
# Out:
#            GENE.NAME  DEGREE  Closeness          Bet        CC     Cl  \
# ENTREZ.ID
# 2617            2617       3      0.277   216.533869  0.000000  15696
# 3190            3190      16      0.304  7464.171467  0.100000  31584
# 3094            3094       1      0.234     0.000000       NaN   2172
# 10130          10130       4      0.263  1616.165675  0.166667   9148
# 9318            9318       3      0.267   192.666251  0.333333   9996
# ...              ...     ...        ...          ...       ...    ...
# 4130            4130       5      0.279  3219.966808  0.100000  16090
# 4735            4735       6      0.271   946.511048  0.133333  12492
# 2915            2915       1      0.243     0.000000       NaN   3191
# 7417            7417       3      0.226  2653.143690  0.000000    903
# 2770            2770       4      0.234    83.745111  0.166667   3359
#
#              Clnorm  SP        PR  sgG5  BRIDGE_sgG5  PROB_sgG5  MIX_sgG5  \
# ENTREZ.ID
# 2617       0.071741   2  0.000479    49     0.358334   0.991976  0.666667
# 3190       0.144414   2  0.002194    36     0.328946   1.000000  0.375000
# 3094       0.009880   3  0.000235    26     0.000000   0.995560  0.000000
# 10130      0.041789   3  0.000793    81     0.247941   1.000000  0.250000
# 9318       0.045668   3  0.000519    47     0.284179   0.999774  0.333333
# ...             ...  ..       ...   ...          ...        ...       ...
# 4130       0.073543   2  0.000817    62     0.497032   0.999967  0.600000
# 4735       0.057085   3  0.000846    12     0.350718   1.000000  0.333333
# 2915       0.014541   2  0.000232    78     0.000000   0.988279  0.000000
# 7417       0.004076   2  0.000777    51     0.296768   0.999977  0.333333
# 2770       0.015310   3  0.000622    37     0.000000   1.000000  0.000000
#
#            BR_CONSENSUS  BR_CONSENSUS_MAD  BR_CONSENSUS_ADJ  DE
# ENTREZ.ID
# 2617           0.358334                 0          0.286215   1
# 3190           0.328946                 0          0.156612   1
# 3094           0.000000                 0         -1.294023   1
# 10130          0.247941                 0         -0.200614   1
# 9318           0.284179                 0         -0.040805   1
# ...                 ...               ...               ...  ..
# 4130           0.497032                 0          0.897864   2
# 4735           0.350718                 0          0.252627   3
# 2915           0.000000                 0         -1.294023   1
# 7417           0.296768                 0          0.014712   1
# 2770           0.000000                 0         -1.294023   1
#
# [343 rows x 17 columns]

# %%
a = [93185, 4099, 2819, 134, 2823, 4744, 84617, 3848, 3849, 79751, 526, 9615, 219537, 3858, 4884, 794, 5019, 3615, 4897, 2596, 292, 25769, 25902, 50, 348980, 308, 1462, 1345, 961, 55753, 586, 203, 2892, 2891, 2893, 4817, 8402, 54996, 478, 5091, 4199, 5095, 622, 6512, 100526833, 23154, 7923, 4724, 1653, 4340, 4978, 126328, 55163, 57468, 8574]
len(a)
len(diff)
# Out:
# 411

# %%
meas = pd.read_csv('Measures_with_DE.csv')
clus = pd.read_csv('../clustering/Clustering/PPI_Network/sgG5_communities.csv',sep='\t')

clus.head()
# Out:
#        #communities
# 273               32
# 1759              32
# 1785              32
# 26052             37
# 1020              32

# %%
thedf = pd.DataFrame()

# sorting by degrees
bydeg = meas.sort_values('DEGREE')
thedf['degrees'] =  list(bydeg['ENTREZ.ID'])
# bydeg.head(10)

#sorting by closeness
bycls = meas.sort_values('Closeness')
thedf['closeness'] = list(bycls['ENTREZ.ID'])

#sorting by bewtweennes
bybet = meas.sort_values('Bet')
thedf['bet'] = list(bybet['ENTREZ.ID'])

#sorting by local centrality
bycl = meas.sort_values('Cl')
thedf['clnorm'] = list(bycl['ENTREZ.ID'])

#sorting by bridgeness
bybr = meas.sort_values('BRIDGE_sgG5')
thedf['bridgeness'] = list(bybr['ENTREZ.ID'])

bybr = meas.sort_values('BR_CONSENSUS')
thedf['br con'] = list(bybr['ENTREZ.ID'])

c = thedf.columns.values
for index, row in thedf.iterrows():
    for i in range(len(c)):
        col = c[i]
#         print(type(thedf[col]))
#         thedf.loc[ thedf[col] in diff, col] = '*'+row[col]  
#         thedf.loc[ thedf[col] in diff2, col] = '*'+row[col]  
#         thedf.loc[ thedf[col] in diff3, col] = '**'+row[col]  

        if(row[col] in diff):
#             thedf.set_index(col,inplace=True)
            thedf.loc[thedf[col] == row[col], col] = '*' + str(row[col])
        if(row[col] in diff2):
#             thedf.set_index(col,inplace=True)
            thedf.loc[thedf[col] == row[col], col] = '*' + str(row[col])
        if(row[col] in diff3):
#             thedf.set_index(col,inplace=True)
            thedf.loc[thedf[col] == row[col], col] = '**' + str(row[col])
        

print(thedf.head(10))
bybr.head(10)
# Out:
#   degrees closeness    bet clnorm bridgeness br con
# 0     483      6217    483   6217        483    483
# 1    3996      9751  56267   9751      11135  11135
# 2    *119     *2664   5532  *2946        162    162
# 3   23603     *2946   3897  *2664      55770  55770
# 4    7464      1537   5213   1537       5372   5372
# 5     833      8834   3996  *4723       *989   *989
# 6    5297     10694   *119   8834      80124  80124
# 7   10768      6507   *966  54828      *2554  *2554
# 8     682     54828  10457  *4540      55739  55739
# 9    6059     *4723    873  55967       8078   8078
#       ENTREZ.ID  GENE.NAME  DEGREE  Closeness         Bet        CC     Cl  \
# 1242        483        483       1      0.218    0.000000       NaN   1211
# 817       11135      11135       1      0.240    0.000000       NaN   3750
# 336         162        162       4      0.241  256.719513  0.000000   2933
# 819       55770      55770       2      0.221    0.000000  1.000000    977
# 820        5372       5372       1      0.200    0.000000       NaN    305
# 822         989        989       6      0.263   20.814065  0.666667  12841
# 332       80124      80124       1      0.249    0.000000       NaN   6351
# 828        2554       2554       1      0.232    0.000000       NaN   2675
# 831       55739      55739       2      0.240    0.000000  1.000000   5062
# 328        8078       8078       1      0.249    0.000000       NaN   6351
#
#         Clnorm  SP        PR  sgG5  BRIDGE_sgG5  PROB_sgG5  MIX_sgG5  \
# 1242  0.005484   4  0.000263     2          0.0   0.996353       0.0
# 817   0.017098   3  0.000237    74          0.0   0.990524       0.0
# 336   0.013361   2  0.000691    69          0.0   1.000000       0.0
# 819   0.004414   3  0.000403    43          0.0   0.999977       0.0
# 820   0.001340   4  0.000330    62          0.0   0.997622       0.0
# 822   0.058681   3  0.000821    12          0.0   1.000000       0.0
# 332   0.028995   3  0.000235    54          0.0   0.988682       0.0
# 828   0.012181   3  0.000242    68          0.0   0.990008       0.0
# 831   0.023099   3  0.000360    68          0.0   0.999902       0.0
# 328   0.028995   3  0.000235    54          0.0   0.988682       0.0
#
#       BR_CONSENSUS  BR_CONSENSUS_MAD  BR_CONSENSUS_ADJ  DE
# 1242           0.0                 0         -1.294023   0
# 817            0.0                 0         -1.294023   0
# 336            0.0                 0         -1.294023   0
# 819            0.0                 0         -1.294023   0
# 820            0.0                 0         -1.294023   0
# 822            0.0                 0         -1.294023   2
# 332            0.0                 0         -1.294023   0
# 828            0.0                 0         -1.294023   1
# 831            0.0                 0         -1.294023   0
# 328            0.0                 0         -1.294023   0

# %%
type(diff)
# Out:
# list
